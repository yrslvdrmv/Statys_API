# %% [markdown]
# # User interface comments

# %% [markdown]
# ## Catalog - Business Manager - Product Variant Pricing Empty

# %% [markdown]
# ![Catalog%20-%20Business%20Manager%20-%20Product%20Variant%20Pricing%20Empty.png](attachment:Catalog%20-%20Business%20Manager%20-%20Product%20Variant%20Pricing%20Empty.png)
